# %% [markdown]
# Make cool charts with Python package. A package in python is a library that adds additional features and tools. Bokeh is a package for creating charts.

# %%
# !pip install -q bokeh

# %%
import bokeh.plotting
bokeh.plotting.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="28c094f5-c1fa-4648-b3cb-c2e934b90764">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, output_file, show

# output to static HTML file
output_file("line.html")

p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="195ae4b4-6d02-467c-a138-46faa8b8d531"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#195ae4b4-6d02-467c-a138-46faa8b8d531").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("195ae4b4-6d02-467c-a138-46faa8b8d531");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '195ae4b4-6d02-467c-a138-46faa8b8d531' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b3be29ca-2df6-44c7-a5f0-8eab5b01efb7":{"roots":{"references":[{"attributes":{},"id":"d82e75e7-562e-4e49-b7a0-eed9108d6051","type":"BasicTicker"},{"attributes":{"callback":null},"id":"e8a2ac5b-ed76-4ff1-99b0-c4ee5961e26a","type":"DataRange1d"},{"attributes":{"plot":{"id":"7264aabb-bb4b-4c21-b356-a1d18e5f0f30","subtype":"Figure","type":"Plot"}},"id":"083e6667-76f2-43c6-92fe-2f8ccfdf1282","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"7264aabb-bb4b-4c21-b356-a1d18e5f0f30","subtype":"Figure","type":"Plot"},"ticker":{"id":"67b48496-fb52-460e-992b-c33bc5e2bb83","type":"BasicTicker"}},"id":"2bd807ae-0684-4dba-9d5a-dd061dff1d62","type":"Grid"},{"attributes":{"overlay":{"id":"e74b013d-5afe-40bc-9d18-cb4b30019c20","type":"BoxAnnotation"},"plot":{"id":"7264aabb-bb4b-4c21-b356-a1d18e5f0f30","subtype":"Figure","type":"Plot"}},"id":"f605bd44-53c1-4001-b9d6-d23bb1acfc72","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"7264aabb-bb4b-4c21-b356-a1d18e5f0f30","subtype":"Figure","type":"Plot"},"ticker":{"id":"d82e75e7-562e-4e49-b7a0-eed9108d6051","type":"BasicTicker"}},"id":"a13c6079-b4db-455f-94a8-ef8a033c1dcd","type":"Grid"},{"attributes":{},"id":"ddc53e80-0499-47b6-b73f-85e327f4afc2","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"7264aabb-bb4b-4c21-b356-a1d18e5f0f30","subtype":"Figure","type":"Plot"}},"id":"aa8fc457-06cb-4101-8448-d4f55b372a99","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"12298a20-ad22-4249-8915-03710bb506c8","type":"ColumnDataSource"},{"attributes":{},"id":"e0a06978-d499-49bc-8dde-a7088beec6f5","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"12298a20-ad22-4249-8915-03710bb506c8","type":"ColumnDataSource"},"glyph":{"id":"2a288bfc-da60-403a-ba92-e215d0c9c80d","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"aa666115-d5ea-476a-899d-178903aa7a6e","type":"Circle"},"selection_glyph":null},"id":"8d9bd124-1236-474f-a486-eca1ff014032","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"43811edd-f9ca-4238-892b-47f7c2333260","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"navy"},"line_alpha":{"value":0.5},"line_color":{"value":"navy"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"2a288bfc-da60-403a-ba92-e215d0c9c80d","type":"Circle"},{"attributes":{"plot":{"id":"7264aabb-bb4b-4c21-b356-a1d18e5f0f30","subtype":"Figure","type":"Plot"}},"id":"69dfe5b0-bae2-4f27-aa9d-90d00e07e397","type":"PanTool"},{"attributes":{"formatter":{"id":"e0a06978-d499-49bc-8dde-a7088beec6f5","type":"BasicTickFormatter"},"plot":{"id":"7264aabb-bb4b-4c21-b356-a1d18e5f0f30","subtype":"Figure","type":"Plot"},"ticker":{"id":"d82e75e7-562e-4e49-b7a0-eed9108d6051","type":"BasicTicker"}},"id":"180b8690-4600-4db8-8f0f-f34db55fb352","type":"LinearAxis"},{"attributes":{"below":[{"id":"ba35d5cd-3f67-4518-95c4-b8aab7a6cf30","type":"LinearAxis"}],"left":[{"id":"180b8690-4600-4db8-8f0f-f34db55fb352","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"ba35d5cd-3f67-4518-95c4-b8aab7a6cf30","type":"LinearAxis"},{"id":"2bd807ae-0684-4dba-9d5a-dd061dff1d62","type":"Grid"},{"id":"180b8690-4600-4db8-8f0f-f34db55fb352","type":"LinearAxis"},{"id":"a13c6079-b4db-455f-94a8-ef8a033c1dcd","type":"Grid"},{"id":"e74b013d-5afe-40bc-9d18-cb4b30019c20","type":"BoxAnnotation"},{"id":"8d9bd124-1236-474f-a486-eca1ff014032","type":"GlyphRenderer"}],"title":{"id":"9699aa00-4911-456b-b318-105dd77eaf32","type":"Title"},"tool_events":{"id":"fcc67ee1-acad-477e-a322-e36428184d95","type":"ToolEvents"},"toolbar":{"id":"4d53dae5-e7e8-4a74-b097-10b0796a8fbc","type":"Toolbar"},"x_range":{"id":"43811edd-f9ca-4238-892b-47f7c2333260","type":"DataRange1d"},"y_range":{"id":"e8a2ac5b-ed76-4ff1-99b0-c4ee5961e26a","type":"DataRange1d"}},"id":"7264aabb-bb4b-4c21-b356-a1d18e5f0f30","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha": ...
