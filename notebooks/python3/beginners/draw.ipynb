# %% [markdown]
# Make cool drawings with symbols - This is called ascii art.

# %%
print("A picture of a dog...")
print(" 0____  ")
print("  ||||  ")
# Out:
# A picture of a dog...
#  0____
#   ||||

# %%
print('''
Ba Ba black sheep
 o-###-
   | |   #
''')
# Out:
# Ba Ba black sheep
#  o-###-
#    | |   #

# %%
print("Make a wave...")
print("/\  "*10)
print("  \/"*10)
# Out:
# Make a wave...
# /\  /\  /\  /\  /\  /\  /\  /\  /\  /\
#   \/  \/  \/  \/  \/  \/  \/  \/  \/  \/

# %%
print('''
City skyline
 

   _|_
  |   |
  |#  |____
  |   |    |
  |  #|  # |
 _|___|_#__|_
''')
# Out:
# City skyline
#
#
#    _|_
#   |   |
#   |#  |____
#   |   |    |
#   |  #|  # |
#  _|___|_#__|_

# %% [markdown]
# Q1 Can you create the cat?
# ![Cat.png](attachment:Cat.png)

# %% [markdown]
# Q2 What else can you create ? - Create and share.
